# %% [markdown]
# Let us read in the metadata first

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/home/nipun/study/datasets/enernoc/meta/all_sites.csv")

# %%
df
# Out:
#     SITE_ID              INDUSTRY                   SUB_INDUSTRY    SQ_FT  \
# 0         6   Commercial Property  Shopping Center/Shopping Mall   161532
# 1         8   Commercial Property  Shopping Center/Shopping Mall   823966
# 2         9   Commercial Property               Corporate Office   169420
# 3        10   Commercial Property  Shopping Center/Shopping Mall  1029798
# 4        12   Commercial Property              Business Services   179665
# 5        13   Commercial Property         Commercial Real Estate   185847
# 6        14   Commercial Property              Business Services  1675720
# 7        21   Commercial Property  Shopping Center/Shopping Mall   783982
# 8        22   Commercial Property        Bank/Financial Services   318130
# 9        25   Commercial Property  Shopping Center/Shopping Mall  1807149
# 10       29   Commercial Property  Shopping Center/Shopping Mall   377537
# 11       30   Commercial Property        Bank/Financial Services   496517
# ...

# %%
df.INDUSTRY.unique()
# Out:
# array(['Commercial Property', 'Education', 'Food Sales & Storage',
#        'Light Industrial'], dtype=object)

# %%
df.groupby("INDUSTRY").count()["INDUSTRY"]
# Out:
# INDUSTRY
# Commercial Property     25
# Education               25
# Food Sales & Storage    25
# Light Industrial        25
# Name: INDUSTRY, dtype: int64

# %%
df_6 = pd.read_csv("/home/nipun/study/datasets/enernoc/csv/6.csv", index_col = "dttm_utc", parse_dates=True, usecols=["dttm_utc","value"])

# %%
df_6
# Out:
#                        value
# dttm_utc
# 2012-01-01 00:10:00  52.1147
# 2012-01-01 00:15:00  50.9517
# 2012-01-01 00:20:00  49.8164
# 2012-01-01 00:25:00  49.1795
# 2012-01-01 00:30:00  47.6288
# 2012-01-01 00:35:00  49.1241
# 2012-01-01 00:40:00  50.3979
# 2012-01-01 00:45:00  51.2840
# 2012-01-01 00:50:00  49.7056
# 2012-01-01 00:55:00  51.6994
# 2012-01-01 01:00:00  49.8441
# 2012-01-01 01:05:00  47.0750
# 2012-01-01 01:10:00  46.8811
# 2012-01-01 01:15:00  45.0812
# 2012-01-01 01:20:00  48.3487
# 2012-01-01 01:25:00  45.3581
# 2012-01-01 01:30:00  42.9767
# 2012-01-01 01:35:00  42.3951
# 2012-01-01 01:40:00  41.8690
# 2012-01-01 01:45:00  41.7029
# 2012-01-01 01:50:00  40.2906
# 2012-01-01 01:55:00  41.6752
# 2012-01-01 02:00:00  39.0168
# 2012-01-01 02:05:00  40.7337
# 2012-01-01 02:10:00  37.6046
# 2012-01-01 02:15:00  38.5461
# 2012-01-01 02:20:00  38.5461
# 2012-01-01 02:25:00  38.9061
# 2012-01-01 02:30:00  39.4322
# 2012-01-01 02:35:00  37.6046
# ...

# %%
df_6.plot()

# %%
df_6.describe()
# Out:
#                value
# count  105385.000000
# mean       31.065302
# std        11.633303
# min         0.000000
# 25%        20.657600
# 50%        31.374100
# 75%        41.038300
# max        71.553900
#
# [8 rows x 1 columns]
