# %%
from nilmtk import DataSet

# %%
ds = DataSet("/Users/nipunbatra/Downloads/redd.h5")

# %%
ds.buildings
# Out:
# OrderedDict([(1, Building(instance=1, dataset='REDD')), (2, Building(instance=2, dataset='REDD')), (3, Building(instance=3, dataset='REDD')), (4, Building(instance=4, dataset='REDD')), (5, Building(instance=5, dataset='REDD')), (6, Building(instance=6, dataset='REDD'))])

# %%
b = ds.buildings[1]

# %%
b
# Out:
# Building(instance=1, dataset='REDD')

# %%
b.metadata
# Out:
# {'dataset': 'REDD', 'instance': 1, 'original_name': 'house_1'}

# %%
b.elec
# Out:
# MeterGroup(meters=
#   ElecMeter(instance=1, building=1, dataset='REDD', site_meter, appliances=[])
#   ElecMeter(instance=2, building=1, dataset='REDD', site_meter, appliances=[])
#   ElecMeter(instance=5, building=1, dataset='REDD', appliances=[Appliance(type='fridge', instance=1)])
#   ElecMeter(instance=6, building=1, dataset='REDD', appliances=[Appliance(type='dish washer', instance=1)])
#   ElecMeter(instance=7, building=1, dataset='REDD', appliances=[Appliance(type='sockets', instance=1)])
#   ElecMeter(instance=8, building=1, dataset='REDD', appliances=[Appliance(type='sockets', instance=2)])
#   ElecMeter(instance=9, building=1, dataset='REDD', appliances=[Appliance(type='light', instance=1)])
#   ElecMeter(instance=11, building=1, dataset='REDD', appliances=[Appliance(type='microwave', instance=1)])
#   ElecMeter(instance=12, building=1, dataset='REDD', appliances=[Appliance(type='unknown', instance=1)])
# ...

# %%
b.elec.load().next()
# Out:
# Loading data for meter ElecMeterID(instance=1, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=2, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=5, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=6, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=7, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=8, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=9, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=11, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=12, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=13, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=14, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=15, building=1, dataset='REDD')
# ...

# %%
mains = b.elec.mains()

# %%
b.elec.dataframe_of_meters(sample_period=60)
# Out:
# Loading data for meter ElecMeterID(instance=3, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=4, building=1, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=10, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=20, building=1, dataset='REDD')
# Done loading data all meters for this chunk.
#                            (1, 1, REDD)  (2, 1, REDD)  (5, 1, REDD)  \
# 2011-04-18 13:22:00+00:00    223.568039    118.939217      6.000000
# 2011-04-18 13:23:00+00:00    226.354340    119.175835      6.000000
# 2011-04-18 13:24:00+00:00    223.398331    121.747169      6.000000
# 2011-04-18 13:25:00+00:00    220.492493    121.880669      5.937500
# 2011-04-18 13:26:00+00:00    220.255661    121.990334      5.937500
# 2011-04-18 13:27:00+00:00    222.951172    122.121666      6.000000
# 2011-04-18 13:28:00+00:00    216.479172    121.531502      6.000000
# ...

# %%
df = _

# %%
df.columns
# Out:
# Index([(1, 1, u'REDD'), (2, 1, u'REDD'), (5, 1, u'REDD'), (6, 1, u'REDD'), (7, 1, u'REDD'), (8, 1, u'REDD'), (9, 1, u'REDD'), (11, 1, u'REDD'), (12, 1, u'REDD'), (13, 1, u'REDD'), (14, 1, u'REDD'), (15, 1, u'REDD'), (16, 1, u'REDD'), (17, 1, u'REDD'), (18, 1, u'REDD'), (19, 1, u'REDD'), ((ElecMeterID(instance=3, building=1, dataset='REDD'), ElecMeterID(instance=4, building=1, dataset='REDD')),), ((ElecMeterID(instance=10, building=1, dataset='REDD'), ElecMeterID(instance=20, building=1, dataset='REDD')),)], dtype='object')

# %%
df.columns = b.elec.get_labels(df.columns)

# %%
b.elec.label()
# Out:
# 'Electric oven, Electric space heater, Site meter, Light, Fridge, Microwave, Electric stove, Unknown, Dish washer, Sockets, Washer dryer'

# %%
df
# Out:
#                             Site meter  Site meter      Fridge  Dish washer  \
# 2011-04-18 13:22:00+00:00   223.568039  118.939217    6.000000     0.142857
# 2011-04-18 13:23:00+00:00   226.354340  119.175835    6.000000     0.285714
# 2011-04-18 13:24:00+00:00   223.398331  121.747169    6.000000     0.437500
# 2011-04-18 13:25:00+00:00   220.492493  121.880669    5.937500     0.187500
# 2011-04-18 13:26:00+00:00   220.255661  121.990334    5.937500     0.500000
# 2011-04-18 13:27:00+00:00   222.951172  122.121666    6.000000     0.312500
# 2011-04-18 13:28:00+00:00   216.479172  121.531502    6.000000     0.133333
# 2011-04-18 13:29:00+00:00   218.805832  119.408836    6.000000     0.250000
# 2011-04-18 13:30:00+00:00   219.138992  119.042999    6.000000     0.250000
# 2011-04-18 13:31:00+00:00   221.331665  119.117165    6.000000     0.312500
# 2011-04-18 13:32:00+00:00   221.328827  119.430504    6.000000     0.375000
# ...

# %%
b.elec.mains().dataframe_of_meters()
# Out:
#                            (1, 1, REDD)  (2, 1, REDD)
# 2011-04-18 09:22:09-04:00    224.190002    118.629997
# 2011-04-18 09:22:10-04:00    225.570007    118.989998
# 2011-04-18 09:22:11-04:00    226.089996    119.050003
# 2011-04-18 09:22:12-04:00    222.740005    118.940002
# 2011-04-18 09:22:13-04:00    222.199997    118.830002
# 2011-04-18 09:22:14-04:00    222.110001    118.690002
# 2011-04-18 09:22:15-04:00    223.139999    119.070000
# 2011-04-18 09:22:16-04:00    223.169998    119.190002
# 2011-04-18 09:22:17-04:00    222.250000    119.099998
# 2011-04-18 09:22:18-04:00    222.639999    119.169998
# 2011-04-18 09:22:19-04:00    221.880005    118.839996
# 2011-04-18 09:22:20-04:00    223.600006    118.919998
# 2011-04-18 09:22:21-04:00    222.210007    119.070000
# 2011-04-18 09:22:22-04:00    222.820007    119.220001
# 2011-04-18 09:22:23-04:00    222.910004    119.160004
# 2011-04-18 09:22:24-04:00    222.809998    119.050003
# ...

# %%
b.elec.submeters().dataframe_of_meters().head()
# Out:
# Loading data for meter ElecMeterID(instance=3, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=4, building=1, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=10, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=20, building=1, dataset='REDD')
# Done loading data all meters for this chunk.
#                            (5, 1, REDD)  (6, 1, REDD)  (7, 1, REDD)  \
# 2011-04-18 13:22:12+00:00             6             0            34
# 2011-04-18 13:22:15+00:00             6             0            34
# 2011-04-18 13:22:18+00:00             6             0            34
# 2011-04-18 13:22:21+00:00             6             1            35
# 2011-04-18 13:22:24+00:00             6             0            34
#
#                            (8, 1, REDD)  (9, 1, REDD)  (11, 1, REDD)  \
# 2011-04-18 13:22:12+00:00            21            81              5
# ...

# %%
b.elec.meters[3].load().next().head()
# Out:
# physical_quantity          power
# type                      active
# 2011-04-18 09:22:13-04:00      0
# 2011-04-18 09:22:16-04:00      0
# 2011-04-18 09:22:20-04:00      0
# 2011-04-18 09:22:23-04:00      1
# 2011-04-18 09:22:26-04:00      0

# %%
b.elec.meters[18].load().next().head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-5364cdfa7179> in <module>()
# ----> 1 b.elec.meters[18].load().next().head()
#
# IndexError: list index out of range

# %%
ds.clear_cache()
# Out:
# Removed building1/elec/cache/meter1/
# Removed building1/elec/cache/meter5/
# Removed building1/elec/cache/meter6/
# Removed building1/elec/cache/meter7/
# Removed building1/elec/cache/meter8/
# Removed building1/elec/cache/meter9/
# Removed building1/elec/cache/meter11/
# Removed building1/elec/cache/meter12/
# Removed building1/elec/cache/meter13/
# Removed building1/elec/cache/meter14/
# Removed building1/elec/cache/meter15/
# Removed building1/elec/cache/meter16/
# Removed building1/elec/cache/meter17/
# Removed building1/elec/cache/meter18/
# Removed building1/elec/cache/meter19/
# Removed building1/elec/cache/meter3/
# Removed building1/elec/cache/meter4/
# Removed building1/elec/cache/meter10/
# Removed building1/elec/cache/meter20/
# Removed building3/elec/cache/meter1/
# Removed building3/elec/cache/meter3/
# Removed building3/elec/cache/meter4/
# Removed building3/elec/cache/meter5/
# Removed building3/elec/cache/meter6/
# Removed building3/elec/cache/meter7/
# ...

# %%
b.elec.meters[3].load().next().head()
# Out:
# physical_quantity          power
# type                      active
# 2011-04-18 09:22:13-04:00      0
# 2011-04-18 09:22:16-04:00      0
# 2011-04-18 09:22:20-04:00      0
# 2011-04-18 09:22:23-04:00      1
# 2011-04-18 09:22:26-04:00      0

# %%
b.elec.submeters().dataframe_of_meters()
# Out:
# Loading data for meter ElecMeterID(instance=3, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=4, building=1, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=10, building=1, dataset='REDD')
# Loading data for meter ElecMeterID(instance=20, building=1, dataset='REDD')
# Done loading data all meters for this chunk.
#                            (5, 1, REDD)  (6, 1, REDD)  (7, 1, REDD)  \
# 2011-04-18 13:22:12+00:00             6             0            34
# 2011-04-18 13:22:15+00:00             6             0            34
# 2011-04-18 13:22:18+00:00             6             0            34
# 2011-04-18 13:22:21+00:00             6             1            35
# 2011-04-18 13:22:24+00:00             6             0            34
# 2011-04-18 13:22:27+00:00             6             0            34
# 2011-04-18 13:22:30+00:00             6             0            33
# ...

# %%
b.elec[3].dataframe_of_meters()
# Out:
# Meter 3 is in a nested meter group. Retrieving just the ElecMeter.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-2f94d46cddfe> in <module>()
# ----> 1 b.elec[3].dataframe_of_meters()
#
# AttributeError: 'ElecMeter' object has no attribute 'dataframe_of_meters'
